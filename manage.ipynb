# %%
import pandas as pd
import numpy as np
import math
import requests

QUANTITY_THRESHOLD = 3
FILE_NAME = 'imspr_materials.xlsx'

xlsx_file = pd.ExcelFile(FILE_NAME)
sheet_names = xlsx_file.sheet_names
print(sheet_names)
# Out:
# ['ProX', 'Pro', 'mini']

# %%
df = pd.read_excel(FILE_NAME, sheet_name=sheet_names[0])
df = df.drop(0)
# Out:
#    iMSPR-ProX 원재료 리스트 (오토샘플러 버전) Unnamed: 1     Unnamed: 2  \
# 1                              1       플루이딕       채널 연결 밸브
# 2                              2       플루이딕      OEM 연동 펌프
# 3                              3       플루이딕          샘플병 캡
# 4                              4       플루이딕        캡 연결 부속
# 5                              5       플루이딕        캡 연결 부속
# 6                              6       플루이딕        샘플, 폐수병
# 7                              7       플루이딕    벌크헤드 유니언 피팅
# 8                              8       플루이딕  Short fitting
# 9                              9       플루이딕    200uL 샘플 루프
# 10                            10       플루이딕   연동펌프 튜빙 연결부속
# 11                            11       플루이딕   연동펌프 튜빙 연결부속
# 12                            12       플루이딕   연동펌프 튜빙 연결부속
# 13                            13       플루이딕       연동 펌프 튜빙
# 14                            14       플루이딕       폐수 연결 포트
# 15                            15       플루이딕       폐수 연결 포트
# 16                            16       플루이딕     플루이딕 모듈 피팅
# 17                            17       플루이딕     플루이딕 모듈 피팅
# 18                            18       플루이딕   연동펌프 튜빙 연결부속
# 19                            19       플루이딕     플루이딕 모듈 피팅
# 20                            20       플루이딕       밸브 연결 부속
# 21                            21         광학          액츄에이터
# 22                            22         광학          폴라라이저
# 23                            23         광학            윈도우
# 24                            24         광학         실린더 렌즈
# 25                            25         광학            프리즘
# 26                            26         광학        아스페릭 렌즈
# 27                            27        디게서       디게싱 카트리지
# 28                            28        디게서           배큠펌프
# 29                            29       잔자푸붐           SMPS
# 30                            30       전자부품            Fan
# 31                            31       플루이딕             오링
# 32                            32         기타        진동방지 고무
# 33                            33         기타        슬라이드 레일
# 34                            34         기타            손잡이
# 35                            35         기타           고무바닥
# 36                            36         기타             자석
# 37                            37       전자부품            PCB
# 38                            38       전자부품        하네스 케이블
# 39                            39       전자부품        하네스 케이블
# 40                            40       전자부품          파워 소켓
# 41                            41       전자부품        USB 케이블
# 42                            42       전자부품         파워 케이블
# 43                            43       전자부품       RS232 모듈
# 44                            44       전자부품        USB 케이블
# 45                           NaN        NaN            NaN
#
#                                            Unnamed: 3              Unnamed: 4  \
# 1                              slide type 3-way valve  MTV-3SL-N32UF-3, 12VDC
# 2                                   OEM Stepper Motor        OEM-B19/MC2 (10)
# 3   T-Series Solvent Bottle Cap for GL45, 3 Luer P...                00945T-3
# 4   T-Series Luer Adaptor to connect 1/16“ OD semi...                   009LA
# 5               Luer to Barb Adaptor 1/16“ Tube, 5/PK                009BA-16
# 6          Square Bottle(GL45) 250ml,64 × 64 × h143mm             DU.21820365
# 7                 Bulkhead Union Assembly PEEK 1/4-28                  P-441N
# 8                      Fingls Sys Shrt PEEK 1/16 10pk                 XP-235X
# 9                                200uL PK Sample Loop                9055-025
# 10                          Conical Adapter Body PEEK                   P-692
# 11  Super Flangeless™ Female Nut PEEK Natural for ...                   P-420
# 12  Super Flangeless™ Ferrule w/SST Ring, Tefzel™ ...                  P-259X
# 13                       3-STP Pharmed 0.25mm ID 12PK                95714-12
# 14                                         원터치 피팅 GPC           GPC-04M5-EPNI
# 15                                        원터치 피팅 GPMM            GPMM-04-EPNI
# 16  Fittings Super Flangeless Ferrule with ss ring...                  M-250X
# 17  F-354X LiteTouch+#174; Nut, FlushNut+#8482;, S...                  F-354X
# 18                    Flangeless Male Nut 1/8in Black                   P-301
# 19  Super Flangeless™ Nut, Standard Knurl, Natural...                  P-255X
# 20  Fitting One-Piece FingerTight Long PEEK 1/16″ ...                  F-130X
# 21                                  Mini Linear Servo              D12-12PT-3
# 22  M22.5 x 0.5 Mounted Linear Glass Polarizing Fi...                 #58-649
# 23          25 x 25mm Uncoated, Gorilla, glass window                 #12-228
# 24                                                NaN                     NaN
# 25                                                NaN                     NaN
# 26                                                NaN                     NaN
# 27                       Asy. Mini DG Ch. PEEK, 100uL               9000-1000
# 28                     ASY,VAC PUMP,AI,SIDE MNT w/PCB               9000-1921
# 29                                            전원공급 장치              LRS-100-12
# 30                                            공기 순환 펜               R127015DM
# 31                                  O링 SS 규격 (U-type)               SS-095-1A
# 32                              Antivibration rubbers                   RA-10
# 33                                                NaN                     NaN
# 34                                                NaN                     NaN
# 35                                               TM-2                     NaN
# 36                                                NaN                     NaN
# 37                                                NaN                     NaN
# 38                                        LED PCB 케이블                       -
# 39                                            디게서 케이블            1460-1295-ND
# 40                                           전원 파워 소켓              IP-0622-H2
# 41                                  USB 2.0 AM-AM 케이블           NMC-C-UA220BK
# 42                                  AC 220V 전원 파워 케이블                     NaN
# 43                                RS232 to uart 변환 모듈             NS-RS232-02
# 44                            USB2.0 연장 고정케이블 [AM-AF]                 ML-U002
# 45                                                NaN                     NaN
#
#                       Unnamed: 5 Unnamed: 6 Unnamed: 7    (1대 생산 기준)  \
# 1                       Takasago        NaN        NaN        801000
# 2                       ShenChen        NaN        NaN        370000
# 3                        Omnifit        NaN        NaN         43000
# 4                        Omnifit      35000          5          7000
# 5                        Omnifit      24000          5          4800
# 6                       4science        NaN        NaN          9240
# 7                           IDEX        NaN        NaN         18119
# 8                           IDEX      42475         10        4247.5
# 9                           IDEX        NaN        NaN         85950
# 10                          IDEX        NaN        NaN         14691
# 11                          IDEX        NaN        NaN          9336
# 12                          IDEX        NaN        NaN          4261
# 13                       ISMATEC     170000         12  14166.666667
# 14                         상아뉴매틱        NaN        NaN           770
# 15                         상아뉴매틱        NaN        NaN          2260
# 16                          IDEX        NaN        NaN           NaN
# 17                          IDEX        NaN        NaN           NaN
# 18                          IDEX        NaN        NaN           NaN
# 19                          IDEX        NaN        NaN           NaN
# 20                          IDEX        NaN        NaN           NaN
# 21                     MightyZAP        NaN        NaN         80000
# 22                 Edmund Optics        NaN        NaN         39000
# 23                 Edmund Optics        NaN        NaN         30600
# 24                           NaN        NaN        NaN           NaN
# 25                           NaN        NaN        NaN           NaN
# 26                           NaN        NaN        NaN           NaN
# 27                        Systec        NaN        NaN        288000
# 28                          IDEX        NaN        NaN        708368
# 29                      MEANWELL        NaN        NaN         15990
# 30                      Everflow        NaN        NaN         28360
# 31                    무사시 오일씰 공업        NaN        NaN           683
# 32                       쿠라시키 화공        NaN        NaN          2820
# 33                           미스미        NaN        NaN           NaN
# 34                           미스미        NaN        NaN           NaN
# 35                           미스미        NaN        NaN           NaN
# 36                           NaN        NaN        NaN           NaN
# 37                           NaN        NaN        NaN           NaN
# 38                             -      66000        100           660
# 39  Trinamic Motion Control GmbH        NaN        NaN           790
# 40                          동일기연        NaN        NaN         11500
# 41                 강원전자(NETmate)        NaN        NaN           770
# 42                    IN NETWORK        NaN        NaN          1590
# 43                   NulSom Inc.        NaN        NaN          5800
# 44                      MachLink        NaN        NaN          1500
# 45                           NaN        NaN        NaN           NaN
#
#    Unnamed: 9  ...    Unnamed: 11   Unnamed: 12  \
# 1           1  ...            유니엘        이학현 대표
# 2           1  ...           레보딕스       박정민 매니저
# 3           2  ...           동우과학        김정권 부장
# 4           5  ...           동우과학        김정권 부장
# 5           2  ...           동우과학        김정권 부장
# 6           2  ...       4science        web 구매
# 7           6  ...     BioNik Inc  Etsuko Shear
# 8           8  ...     BioNik Inc  Etsuko Shear
# 9           1  ...     BioNik Inc  Etsuko Shear
# 10          1  ...     BioNik Inc  Etsuko Shear
# 11          1  ...     BioNik Inc  Etsuko Shear
# 12          1  ...     BioNik Inc  Etsuko Shear
# 13          1  ...           레보딕스       박정민 매니저
# 14          1  ...            미스미        web 구매
# 15          1  ...            미스미        web 구매
# 16         11  ...            NaN           NaN
# 17          3  ...            NaN           NaN
# 18          1  ...            NaN           NaN
# 19          3  ...            NaN           NaN
# 20          3  ...            NaN           NaN
# 21          1  ...           모터뱅크        web 구매
# 22          2  ...  Edmund Optics        web 구매
# 23          2  ...  Edmund Optics        web 구매
# 24          1  ...            NaN           NaN
# 25          1  ...            NaN           NaN
# 26          1  ...            NaN           NaN
# 27          1  ...     BioNik Inc  Etsuko Shear
# 28          1  ...     BioNik Inc  Etsuko Shear
# 29          1  ...          나비엠알오             -
# 30          1  ...        IC shop             -
# 31          1  ...            미스미        web 구매
# 32          6  ...            미스미        web 구매
# 33          2  ...            NaN           NaN
# 34          1  ...            NaN           NaN
# 35          6  ...            NaN           NaN
# 36          4  ...            NaN           NaN
# 37          1  ...            NaN           NaN
# 38          1  ...         디바이스마트        이승진 대리
# 39          1  ...         디바이스마트        이승진 대리
# 40          1  ...         디바이스마트        이승진 대리
# 41          1  ...         디바이스마트        이승진 대리
# 42          1  ...         디바이스마트        이승진 대리
# 43          1  ...         디바이스마트        이승진 대리
# 44          1  ...         디바이스마트        이승진 대리
# 45        NaN  ...            NaN           NaN
#
#                                           Unnamed: 13    Unnamed: 14  \
# 1                                  uniel2001@daum.net   031-705-1791
# 2                                 sales@revodix.co.kr  010-3245-3253
# 3                                  kimjg@laball.co.kr  010-3519-0713
# 4                                  kimjg@laball.co.kr  010-3519-0713
# 5                                  kimjg@laball.co.kr  010-3519-0713
# 6   https://www.4science.net/goods/detail.do?glt_n...            NaN
# 7                                  info@bionikinc.com              -
# 8                                  info@bionikinc.com              -
# 9                                  info@bionikinc.com              -
# 10                                 info@bionikinc.com              -
# 11                                 info@bionikinc.com              -
# 12                                 info@bionikinc.com              -
# 13                                sales@revodix.co.kr  010-3245-3253
# 14  https://kr.misumi-ec.com/vona2/detail/22100566...              -
# 15  https://kr.misumi-ec.com/vona2/detail/22100566...              -
# 16                                                NaN            NaN
# 17                                                NaN            NaN
# 18                                                NaN            NaN
# 19                                                NaN            NaN
# 20                                                NaN            NaN
# 21                          https://www.motorbank.kr/              -
# 22  https://www.edmundoptics.co.kr/p/m225-x-05-mou...              -
# 23  https://www.edmundoptics.co.kr/p/25-x-25mm-unc...              -
# 24                                                NaN            NaN
# 25                                                NaN            NaN
# 26                                                NaN            NaN
# 27                                 info@bionikinc.com              -
# 28                                 info@bionikinc.com            NaN
# 29                  https://www.navimro.com/g/447735/              -
# 30  http://hit100.co.kr/product/detail.html?produc...              -
# 31  https://kr.misumi-ec.com/vona2/detail/22100061...              -
# 32                          https://kr.misumi-ec.com/            NaN
# 33                                                NaN            NaN
# 34                                                NaN            NaN
# 35                                                NaN            NaN
# 36                                                NaN            NaN
# 37                                                NaN            NaN
# 38                                 lsj653@ntrex.co.kr  010-6359-0223
# 39  https://www.devicemart.co.kr/goods/view?no=106...  010-6359-0223
# 40    https://www.devicemart.co.kr/goods/view?no=1519  010-6359-0223
# 41  https://www.devicemart.co.kr/goods/view?no=109...  010-6359-0223
# 42  https://www.devicemart.co.kr/goods/view?no=122...  010-6359-0223
# 43  https://www.devicemart.co.kr/goods/view?no=115...  010-6359-0223
# 44  https://www.devicemart.co.kr/goods/view?no=109...  010-6359-0223
# 45                                                NaN            NaN
#
#      Unnamed: 15     Unnamed: 16 Unnamed: 17 Unnamed: 18          Unnamed: 19  \
# 1            NaN               2           2       3개 발주  2023-01-30 00:00:00
# 2   pump head 포함               5           5         NaN                  NaN
# 3            NaN              41        20.5         NaN                  NaN
# 4            NaN             143        28.6         NaN                  NaN
# 5            NaN              42          21         NaN                  NaN
# 6            NaN              20          10         NaN                  NaN
# 7            NaN              10    1.666667      40개 주문  2023-01-31 00:00:00
# 8            NaN              54        6.75       2개 주문  2023-01-31 00:00:00
# 9            NaN               5           5       5개 주문  2023-01-31 00:00:00
# 10           NaN              12          12         NaN                  NaN
# 11           NaN              26          26         NaN                  NaN
# 12           NaN              41          41         NaN                  NaN
# 13           NaN              79          79         NaN                  NaN
# 14           NaN              43          43         NaN                  NaN
# 15           NaN              28          28         NaN                  NaN
# 16           NaN              40    3.636364       5개 주문  2023-01-31 00:00:00
# 17           NaN              53   17.666667         NaN                  NaN
# 18           NaN              31          31         NaN                  NaN
# 19           NaN              47   15.666667         NaN                  NaN
# 20           NaN              67   22.333333         NaN                  NaN
# 21           NaN               6           6         NaN                  NaN
# 22           NaN              11         5.5         NaN                  NaN
# 23           NaN              12           6         NaN                  NaN
# 24           NaN              43          43         NaN                  NaN
# 25           NaN               7           7         NaN                  NaN
# 26           NaN               4           4         NaN                  NaN
# 27           NaN               8           8         NaN                  NaN
# 28           NaN               5           5       5개 주문  2023-01-26 00:00:00
# 29           NaN               6           6         NaN                  NaN
# 30           NaN               9           9         NaN                  NaN
# 31           NaN              29          29         NaN                  NaN
# 32           NaN             107   17.833333         NaN                  NaN
# 33           NaN              15         7.5         NaN                  NaN
# 34           NaN               8           8         NaN                  NaN
# 35           NaN              64   10.666667         NaN                  NaN
# 36           NaN              98        24.5         NaN                  NaN
# 37           NaN              10          10         NaN                  NaN
# 38           NaN              90          90         NaN                  NaN
# 39           NaN              12          12         NaN                  NaN
# 40           NaN              10          10         NaN                  NaN
# 41           NaN              10          10         NaN                  NaN
# 42           NaN              10          10         NaN                  NaN
# 43           NaN              10          10         NaN                  NaN
# 44           NaN              10          10         NaN                  NaN
# 45           NaN  ProX 생산 가능 대수     1.666667         NaN                  NaN
#
#    Unnamed: 20
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# 38         NaN
# 39         NaN
# 40         NaN
# 41         NaN
# 42         NaN
# 43         NaN
# 44         NaN
# 45         NaN
#
# [45 rows x 21 columns]

# %%
available_number_column = df.iloc[:,17].astype(float)
min_value = available_number_column.min()
available_number = math.floor(min_value)
print(f"{available_number} products can be produced!")
# Out:
# 1 products can be produced!

# %%
is_lacked_idx = np.where(available_number_column < QUANTITY_THRESHOLD)
available_name = df.iloc[is_lacked_idx[0], 2]

print(available_name.dropna())
# Out:
# 1       채널 연결 밸브
# 7    벌크헤드 유니언 피팅
# Name: Unnamed: 2, dtype: object

# %%
# # Check if there are enough materials to produce at least one product
# if products_available == 0 or not lacked_materials.empty:
#     # Send a message to Slack

# %%
slack_webhook_url = 'https://hooks.slack.com/services/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'
slack_message = {'text': 'Alert: Not enough materials to produce a product!'}
# if not lacked_materials.empty:

# slack_message['text'] += '\n\nLacked materials:\n' + lacked_materials.to_string(index=False)
response = requests.post(slack_webhook_url, json=slack_message)

if response.status_code != 200:
    raise ValueError('Failed to send Slack message: %s' % response.text)
